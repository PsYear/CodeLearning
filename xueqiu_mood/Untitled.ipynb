# %%
#coding:utf-8
import requests
import bs4
from bs4 import BeautifulSoup

socks = "SZ000002"
headers = { "User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/53.0.2785.116 Safari/537.36"
            }

session = requests.session()
url = "https://xueqiu.com/s/"+socks
cont = session.get(url,headers=headers).content
# cont

# %%
unicode_str = unicode(cont, encoding='utf-8')
print unicode_str.encode('utf-8')
# Out:
# <!DOCTYPE html><html lang="zh-CN"><head><meta http-equiv="X-UA-Compatible" content="IE=edge"><meta charset="utf-8"><meta property="qc:admins" content="10210420621156375"><meta name="renderer" content="webkit"><title>万科A(SZ000002)的股票股价,行情,新闻,财报,数据 - 雪球</title><script>var _write = document.write;
# var write = function (str) {
#   SNB = window.SNB || {};
#   if (_write.apply) {
#     SNB.docWrite = function (str) {
#       _write.apply(document, arguments);
#     }
#   } else {
#     SNB.docWrite = _write;
#   }
# };
#
# document.write = write;
# </script><meta name="keywords" content="000002,万科,招保万金,雪球,雪球财经,万科A行情,万科A交易,万科A新闻,万科A资讯,万科A价格,万科A实时行情,万科A资金流向,万科A研究报告,万科A点评,万科A讨论,万科A财报,万科A财务分析"><meta name="description" content="万科A(SZ000002)的股票股价,行情,新闻,财报,数据,000002,万科,招保万金,雪球,雪球财经,万科A行情,万科A交易,万科A新闻,万科A资讯,万科A价格,万科A实时行情,万科A资金流向,万科A研究报告,万科A点评,万科A讨论,万科A财报,万科A财务分析"><!--<link rel="shortcut icon" href="http://xueqiu.com/favicon.ico">--><link rel="icon" type="image/png" href="https://assets.imedao.com/images/favicon.png"><style>html {display:none}</style><script>if (self == top) {
#   document.documentElement.style.display = 'block';
# } else if (top.location.host !== 'xueqiu.com') {
#   top.location = self.location;
# }
# var WATCH = {};
# WATCH.appStart = 1492387447901
# WATCH.pageStart = (new Date()).getTime()</script><link rel="stylesheet" href="https://assets.imedao.com/style/bootstrap-b864c5.css"><style>body{
#   padding-top:40px;
# }
# /* TODO */
# .search .dropdown-menu strong{
#   height:12px;
#   line-height:12px;
# }</style><link rel="apple-touch-icon-precomposed" href="https://assets.imedao.com/images/icon-144.png"><script src="https://assets.imedao.com/js/xdomain-0.6.15.js"></script><script>xdomain.slaves({
#   'https://xueqiu.com': '/proxy2.html',
#   'https://im0.xueqiu.com': '/proxy2.html',
#   'https://im1.xueqiu.com': '/proxy2.html',
#   'https://im2.xueqiu.com': '/proxy2.html',
#   'https://im3.xueqiu.com': '/proxy2.html',
#   'https://im4.xueqiu.com': '/proxy2.html',
#   'https://im5.xueqiu.com': '/proxy2.html',
#   'https://im6.xueqiu.com': '/proxy2.html',
#   'https://im7.xueqiu.com': '/proxy2.html',
#   'https://im8.xueqiu.com': '/proxy2.html',
#   'https://im9.xueqiu.com': '/proxy2.html'
# });</script><script src="https://assets.imedao.com/js/SNB.lib.bundle-b11b47.js"></script></head><body id="jade-singleStock" class="left right oppositeColor  isPC isNotMobile isNotPad"><script>SNB = window.SNB || {};
# jQuery.extend(SNB, {
#   data: {},
#   env: "production",
#   Views: {},
#   Templates: {},
#   Models: {},
#   Collections: {},
a17f1a","performance-year.css":"317994","performanceChart.css":"2589d4","personality-ie8.css":"6a37b0","personality.css":"c723c4","pop_login.css":"8f20df","portfolioIframe.css":"c85adf","portfolioNew.css":"4f2887","profile.css":"0737fc","profile_info.css":"2bb9ad","profile_operations.css":"a0abbd","profile_status.css":"3969fd","pull-to-refresh.css":"3e5b69","qa.css":"c736e1","red-envelope.css":"766da0","reward.css":"14f3a2","searchBar.css":"aeef28","simplePagination.css":"b23401","snowbrick.css":"852420","square.css":"790e6a","status_mobile.css":"625b26","status_operate_btn.css":"0872af","tab-setting.css":"506d45","today_topic.css":"e4ea6a","tooltip.css":"820355","uploadify.css":"d5b49f","userRecommend.css":"beabbe","user_list.css":"bb06fd","variable.css":"d41d8c","widget.css":"88e99b","widget_user.css":"d1e0c0","article/m.css":"acab62","common/base.css":"38f3fe","common/form.css":"4839e9","common/grid.css":"c165dd","common/iconfont.css":"7a16a2","common/iconfont2.css":"854528","common/layout.css":"746a95","common/menu.css":"985468","common/mobile.css":"3362b1","common/mod.css":"c15889","common/modal.css":"865ee2","common/nav-bar.css":"ebb55d","common/pager.css":"0d5b09","common/regist-guide.css":"2ecd55","common/reset.css":"e2dffc","common/var.css":"d41d8c","cube/cube-analyze.css":"3d43f3","cube/cube_card.css":"a56e9f","cube/cube_detail.css":"91c06e","cube/cube_detail_m.css":"6978cc","cube/cube_discover.css":"328573","cube/cube_discover_m.css":"32a394","cube/cube_edit.css":"f5208f","cube/cube_sell_notice_dialog.css":"913dc6","editor/index.css":"74e2e9","editor/modal.css":"88f071","editor/normalize.css":"709c92","fund/fund_bottom.css":"94a2b8","fund/fund_detail.css":"f3eade","fund/fund_dialog-mobile.css":"e3c4b8","fund/fund_dialog.css":"fc8fcc","fund/fund_home.css":"3bddb2","lib/animate.css":"8bea50","lib/animate.min.css":"b78a94","lib/jquery.fullPage.css":"3dfa38","lib/jquery.fullPage.new.css":"d4d4ba","lib/swiper.min.css":"9da938","pages/TSNB.about.css":"28449a","pages/home.css":"562d78","pages/imeigu.css":"cff846","pages/post.css":"79b509","pages/profile.css":"8df782","pages/status.css":"72d8cf","pages/tip.css":"9bc5a0","profiles/m.css":"1458c3","status/components_m.css":"738f36","status/offer.css":"553271","status/user.css":"678907","tactics/push.css":"ca2d74","touch/common.css":"1c57df","touch/normal.css":"d536b7","widget/TSNB.comment.css":"c82d02","widget/TSNB.donate.css":"708f8a","widget/TSNB.donate_tooltip.css":"672acf","widget/TSNB.performance.css":"588cce","widget/TSNB.portfolio_dialog.css":"f7ca7d","widget/TSNB.portfolio_user_dialog.css":"9ad4f2","widget/TSNB.report_spam.css":"3e795c","widget/TSNB.share.css":"f36d77","widget/TSNB.status.css":"1435c2","widget/TSNB.user_dialog.css":"81075a","widget/ask.css":"887dea","widget/btn.css":"9fdda0","widget/column_cell.css":"7c1170","widget/datepicker.css":"d683e7","widget/donate ...
#   staticDomain: 'https://assets.imedao.com',
#   bid : ''
# });
#
# SNB.data.access_token =  $.cookie("xq_a_token") || "ca292f8d934efc28f3fd052b7dcf46f14a20a0d3";
# </script><!-- 防止局域网缓存用户信息--><script>(function(){
#   var search = window.location.search || '';
#   if (search.indexOf('_=') === -1 && SNB.bid !== '' && document.cookie && document.cookie.indexOf('bid=' + SNB.bid) === -1) {
#     var searchArr = search.split('&');
#     searchArr.push('_=' + (+new Date).toString(36));
#     window.location.search = search.join('&');
#   }
# })();
# </script><script src="https://assets.imedao.com/js/05.jquery.cookie.js"></script><script>function delCookie(name){//为了删除指定名称的cookie，可以将其过期时间设定为一个过去的时间
#   var date = new Date();
#   date.setTime(date.getTime() - 10000);
#   document.cookie = name + '=a; expires=' + date.toGMTString();
# }
# /*
# if(!$.cookie('xq_refresh') && $.cookie('xq_a_token')){
#   $.ajax({
#     url: '/user/refreshCookie',
#     async: false
#   }).done(function(){
#     delCookie('xq_a_token');
#     delCookie('xq_r_token');
#     delCookie('xq_token_expire');
#   });
# }
# */
# jQuery(function($){
#   $('.navbar a.exit').on('click', function(){
#     try{
#       delCookie('xq_a_token');
#       delCookie('xq_r_token');
#       delCookie('xq_token_expire');
#     } catch(e){
#       console.log(e);
#     }
#   });
# });</script><script src="https://assets.imedao.com/js/SNB.helpers-2731ed.js"></script><script>SNB.profileUser = SNB.currentUser</script><noscript><style>html {
#   display: block
# }</style><p class="ie6">当前浏览器禁用了JavaScript，导致不能正常使用雪球的功能，请打开JavaScript后再访问本站。</p></noscript><!--[if lt IE 8]><div class="ie6">你正在使用的浏览器版本过低（IE7或IE7以下，包括套用了IE内核的360浏览器、搜狗浏览器等）。<br />如果不能正常浏览本站或某些功能无法使用，请到微软官网下载升级 <a href="http://windows.microsoft.com/zh-CN/internet-explorer/downloads/ie">Internet Explorer</a> 或使用 <a href="http://www.google.com/chrome/">谷歌 Google Chrome</a> 浏览器。</div><![endif]--><div class="temp"></div><div class="navbar navbar-fixed-top"><div class="navbar-inner"><div class="container"><h1 id="logo"><a href="/" title="返回我的首页"><img src="https://assets.imedao.com/images/logos/logo.2015.png" alt="雪球" class="logo-type"><img src="https://assets.imedao.com/images/logos/logotype.2015.png" alt="雪球" style="width: 48px;"></a></h1><div class="search"><form method="get" action="/k"><input id="quick-search" name="q" type="text" autocomplete="off" placeholder="搜索 股票/讨论/用户/组合/群组" class="typeahead"></form><span class="icon"><i></i></span></div><ul class="nav pull-right account notlogined"><li><a href="/account/reg" id="nav-signup-link" class="reg">注册</a></li><li><a href="/" id="nav-login-link" class="login">登录</a></li></ul></div></div></div><!--!=css('im.css')--><script>seajs.config({
#   timeout: 60000,
#   preload: [SNB.jsVersion && _.keys(SNB.jsVersion).length ? 'SNB.base-' + SNB.jsVersion['SNB.base.js'] + '.js' : 'SNB.base.js']
# })
# </script><script>SNB.getJS = function (path) {
#   if (!path) {
#     return '';
#   }
#   if (!config.js || !config.js[path]) {
#     return SNB.staticDomain.js + '/' + path;
#   }
#   var arr = path.split('.');
#   var len = arr.length;
#   arr[len - 2] = arr[len - 2] + '-' + config.js[path];
#   return SNB.staticDomain.js + '/' + arr.join('.');
# };
# seajs.use("SNB.guest.js")
# seajs.use('widget/util/user');
# </script><script>;(function () {
#   var keys = _.keys(SNB.jsVersion)
#     , map = [];
#
#   if (keys.length) {
#     _.each(keys, function(k) {
#       var reg = new RegExp('\\/(' + k.replace(/\./g, '\\.') + ')(\\?.*|$)');
#
#       map.push([reg, function (all, fileName, param) {
#         var result = '/' + fileName.replace(/\.js$/i, '') + '-' + SNB.jsVersion[k] + '.js';
#
#         if (param) {
#           result += param;
#         }
#
#         return result;
#       }]);
#     });
#
#     seajs.config({
#       map: map
#     });
#   }
# }())
# </script><!-- test config--><script src="https://assets.imedao.com/js/bootstrap-6bd6fa.js"></script><div id="center" class="container"><div class="left-sidebar"><div class="wrapper"><div class="widget"><style>.stockLinks ul{
#   border-top:1px solid #f1f1f1;
#   margin:5px 0px 15px 0px;
#   padding-top:5px;
#   padding-left:10px;
#   font-size:13px;
# }
# .stockLinks li{
#   height:23px;
# }
# .stockLinks li a{
#   color:black;
# }
# .stockLinks strong{
#   padding-left:10px;
# }</style><div class="stockLinks"><strong>公司概况</strong><ul><li><a href='http://xueqiu.com/S/SZ000002/GSJJ' target='_blank'>公司简介</a></li><li><a href='http://stockpage.10jqka.com.cn/000002/company/#manager' target='_blank'>公司高管</a></li><li><a href='http://stock.jrj.com.cn/share,000002,zgsms.shtml' target='_blank'>IPO文件</a></li></ul><strong>股权信息</strong><ul><li><a href='http://xueqiu.com/S/SZ000002/GBJG' target='_blank'>股本结构</a></li><li><a href='http://xueqiu.com/S/SZ000002/ZYGD' target='_blank'>主要股东</a></li><li><a href='http://xueqiu.com/S/SZ000002/LTGD' target='_blank'>流通股东</a></li><li><a href='http://stock.jrj.com.cn/share,000002,jjcg.shtml' target='_blank'>基金持股</a></li><li><a href='http://hq.emoney.cn/f10/Wf10/ggda/000002.html' target='_blank'>高管持股</a></li><li><a href='http://xueqiu.com/S/SZ000002/GDHS' target='_blank'>股东户数</a></li><li><a href='http://xueqiu.com/S/SZ000002/XSGDMD' target='_blank'>限售股东</a></li></ul><strong>股票交易</strong><ul><li><a href='http://stockhtm.finance.qq.com/sstock/quotpage/q/000002.htm#detail' target='_blank'>成交明细</a></li><li><a href=' http://stockhtm.finance.qq.com/sstock/quotpage/q/000002.htm#price' target='_blank'>分价表</a></li><li><a href='http://quotes.money.163.com/trade/ddtj_000002.html' target='_blank'>大单统计</a></li><li><a href='http://data.eastmoney.com/dzjy/detail/000002.html' target='_blank'>大宗交易</a></li><li><a href='http://xueqiu.com/S/SZ000002/LHB' target='_blank'>龙虎榜数据</a></li><li><a href='http://stockdata.stock.hexun.com/rzrq/s000002.shtml' target='_blank'>融资融券</a></li></ul><strong>公司公告</strong><ul><li><a href='http://disclosure.szse.cn/m/drgg.htm' target='_blank'>最新公告</a></li><li><a href='http://money.finance.sina.com.cn/corp/go.php/vCB_Bulletin/stockid/000002/page_type/ndbg.phtml' target='_blank'>年度报告</a></li></ul><strong>公司运作</strong><ul><li><a href='http://money.finance.sina.com.cn/corp/go.php/vGP_StockHolderMeeting/stockid/000002.phtml' target='_blank'>股东大会</a></li><li><a href='http://stockpage.10jqka.com.cn/000002/operate/#analysis' target='_blank'>收入构成</a></li><li><a href='http://q.stock.sohu.com/cn/000002/bw.shtml' target='_blank'>重大事项</a></li><li><a href='http://xueqiu.com/S/SZ000002/FHPS' target='_blank'>分红送配</a></li><li><a href='http://xueqiu.com/S/SZ000002/ZFYLB' target='_blank'>增发一览</a></li><li><a href='http://xueqiu.com/hq/insider/SZ000002' target='_blank'>内部交易</a></li><li><a href='http://irm.cninfo.com.cn/ssessgs/S000002/index.html' target='_blank'>IR活动记录</a></li></ul><strong>财务数据</strong><ul><li><a href='http://stockhtm.finance.qq.com/sstock/quotpage/q/000002.htm#10' target='_blank'>业绩预告</a></li><li><a href='http://xueqiu.com/S/SZ000002/ZYCWZB' target='_blank'>主要财务指标</a></li><li><a href='http://xueqiu.com/S/SZ000002/MRCWZB' target='_blank'>当日财务指标</a></li><li><a href='http://xueqiu.com/S/SZ000002/DJCWZB' target='_blank'>单季财务指标</a></li><li><a href='http://xueqiu.com/S/SZ000002/GSLRB' target='_blank'>综合损益表</a></li><li><a href='http://xueqiu.com/S/SZ000002/ZCFZB' target='_blank'>资产负债表</a></li><li><a href='http://xueqiu.com/S/SZ000002/XJLLB' target='_blank'>现金流量表</a></li><li><a href='http://xueqiu.com/S/SZ000002/GPSYLZB' target='_blank'>股票收益率指标</a></li><li><a href='http://vip.stock.finance.sina.com.cn/corp/go.php/vFD_BenifitChange/stockid/000002/displaytype/4.phtml ' target='_blank'>所有者权益变动</a></li><li><a href='http://xueqiu.com/hq/screener/CN' target='_blank'>雪球选股器</a></li></ul><strong>研究分析</strong><ul><li><a href='http://quotes.money.163.com/f10/dbfx_000002.html' target='_blank'>杜邦分析</a></li><li><a href='http://vip.stock.finance.sina.com.cn/q/go.php/vReport_List/kind/search/index.phtml?t1=2&symbol=000002' target='_blank'>研究报告</a></li></ul></div></div></div></div><div class="main"><div style="display:none" class="loading"></div><div class="wrapper"><link rel="stylesheet" href="https://assets.imedao.com/style/pages/invest/singleStock-5049bf.css"><link rel="stylesheet" href="https://assets.imedao.com/style/jquery.ui-279647.css"><link rel="stylesheet" href="https://assets.imedao.co ...
#   <div class="reward-container">
#     <div class="reward-modal-hd">现金打赏
#       <div class="close"></div>
#     </div>
#     <div class="reward-modal-bd">
#       <div class="payment-mod">
#         <div class="reward-amount-mod">
#           <div class="reward-amount-hd">欢迎打赏，请选择打赏金额</div>
#           <div class="reward-amount-bd">
#             <div class="reward-amount-grid">
#               <div data-amount="1" class="reward-amount-item active">1 元</div>
#               <div data-amount="6" class="reward-amount-item">6 元</div>
#               <div data-amount="10" class="reward-amount-item">10 元</div>
#               <div data-amount="66" class="reward-amount-item">66 元</div>
#               <div data-amount="100" class="reward-amount-item">100 元</div>
#               <div class="reward-amount-other">其他金额</div>
#               <div class="reward-amount-custom hidden empty">
#                 <input type="text" placeholder="可填写1-200"/>
#               </div>
#             </div>
#           </div>
#         </div>
#         <% if (wallet > 0) { %>
#           <div class="reward-payment-mod reward-payment-layout-3">
#             <div class="reward-payment wechat checked">
#               <span>微信支付</span>
#               <div class="check-radio"></div>
#             </div>
#             <div class="reward-payment alipay">
#               <span>支付宝支付</span>
#               <div class="check-radio"></div>
#             </div>
#             <div class="reward-payment wallet">
#               <span>余额支付
#                 <i class="wallet-amount">可用余额<%= wallet %>元</i>
#               </span>
#               <div class="check-radio"></div>
#             </div>
#           </div>
#         <% } else { %>
#           <div class="reward-payment-mod reward-payment-layout-2">
#             <div class="reward-payment wechat">
#               <span>微信支付</span>
#               <div class="check-radio"></div>
#             </div>
#             <div class="reward-payment alipay">
#               <span>支付宝支付</span>
#               <div class="check-radio"></div>
#             </div>
#           </div>
#         <% } %>
#         <div class="reward-submit-mod">
#           <div class="reward-modal-btn pay-btn">立即支付</div>
#           <div class="reward-member-terms">
#             <div class="reward-ft-lf">支付即代表同意 <a href="/law/reward" target="_blank">雪球打赏协议</a></div>
#             <div class="reward-ft-rt reward-by-snowicon hidden"><a href="">使用雪球币打赏</a></div>
#           </div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div></script><script id="donateAmountTemplate" type="x-template"><div id="donateAmountModal" class="donate-modal reward-modal dimmer center middle hidden">
#   <div class="reward-container">
#     <div class="reward-modal-hd">雪球币打赏
#       <div class="close"></div>
#     </div>
#     <div class="reward-modal-bd">
#       <div class="payment-mod">
#         <div class="reward-amount-mod">
#           <div class="reward-amount-hd">欢迎打赏，请选择打赏金额</div>
#           <div class="reward-amount-bd">
#             <div class="reward-amount-grid">
#               <div data-amount="1" class="reward-amount-item active">1 雪球币</div>
#               <div data-amount="6" class="reward-amount-item">6 雪球币</div>
#               <div data-amount="10" class="reward-amount-item">10 雪球币</div>
#               <div data-amount="66" class="reward-amount-item">66 雪球币</div>
#               <div data-amount="100" class="reward-amount-item">100 雪球币</div>
#               <div class="reward-amount-custom">
#                 <input type="text" placeholder="其他金额"/>
#               </div>
#             </div>
#           </div>
#         </div>
#         <div class="reward-submit-mod">
#           <div class="donate-detail">
#             应付：<span class="donate-amount"></span>雪球币；账号余额：<span class="donate-balance"></span>雪球币
#           </div>
#           <div class="donate-error hidden">
#           </div>
#           <div class="reward-modal-btn pay-btn">立即支付</div>
#         </div>
#       </div>
#     </div>
#   </div>
# </div></script><script id="qrcodeTemplate" type="x-template"><div id="qrcodeModal" class="reward-modal dimmer center middle hidden">
#   <div class="reward-container">
#     <div class="reward-modal-hd">微信扫码支付
#       <div class="close"></div>
#     </div>
#     <div class="reward-modal-bd">
#       <div class="qrcode-container">
#         <p class="qrcode-title">支付金额 <span class="wechat-amount">20.00</span> 元</p>
#         <img src=""/>
#         <p class="qrcode-desc">打开手机微信“扫一扫”</p>
#       </div>
#     </div>
#   </div>
# </div></script><script id="successTemplate" type="x-template"><div id="successModal" class="reward-modal dimmer center middle hidden">
#   <div class="reward-container">
#     <div class="reward-modal-hd">现金打赏
#       <div class="close"></div>
#     </div>
#     <div class="reward-modal-bd">
#       <div class="pay-success">
#         <div class="reward-result-mod success">
#           <div class="reward-result-heading">感谢打赏</div>
#           <p>成功打赏该<%= type %>￥<%= amount %></p>
#         </div>
#         <div class="reward-modal-btn reward-share blue">分享到雪球动态</div>
#       </div>
#     </div>
#   </div>
# </div>
# </script><script id="walletConfirmTpl" type="x-template"><div id="walletConfirmModal" class="reward-modal dimmer center middle hidden">
#   <div class="reward-container">
#     <div class="reward-modal-hd">提示
#       <div class="close"></div>
#     </div>
#     <div class="reward-modal-bd">
#       <p>请确认是否用余额支付 <%= amount %> 元</p>
#       <div class="reward-modal-btn deny gray">取消</div>
#       <div class="reward-modal-btn define blue">确认</div>
#     </div>
#   </div>
# </div></script><script>var stockData = {};
# stockData.stockInfo = {"type":"股票","name":"万科A","exchange":"沪深","money":"￥","is$":false,"isMF":false,"isFuture":false,"isPF":false,"isTP":false,"isFP":false,"isBStock":false,"stockid":"SZ000002","moneyType":"￥","last_close":"20.94","current":"20.64","symbol":"SZ000002","stockType":"股票","my_id":"4342102154","analyst_id":"3906346776","code":"000002"};
# SNB.data.lastClose = 20.94;
# SNB.data.quote = {"symbol":"SZ000002","exchange":"SZ","code":"000002","name":"万科A","current":"20.64","percentage":"-1.43","change":"-0.30","open":"20.92","high":"20.92","low":"20.60","close":"20.64","last_close":"20.94","high52week":"29.00","low52week":"16.02","volume":"2185.06万","volumeAverage":"6468.23万","marketCapital":"2278.48亿","eps":"1.90","pe_ttm":"10.8382","pe_lyr":"10.8382","beta":"-","totalShares":"110.39亿","time":"Fri Apr 14 15:04:03 +0800 2017","afterHours":"20.64","afterHoursPct":"0.00","afterHoursChg":"0.00","updateAt":"1486027848539","dividend":"0.72","yield":"3.49","turnover_rate":"0.23%","instOwn":"-","rise_stop":"23.03","fall_stop":"18.85","currency_unit":"CNY","amount":"4.52亿","net_assets":"10.28","hasexist":"-","has_warrant":"-","type":"11","flag":"1","rest_day":"","amplitude":"1.53%","market_status":"未开盘","lot_size":"100","min_order_quantity":"-","max_order_quantity":"-","tick_size":"0.01","kzz_stock_symbol":"02202","kzz_stock_name":"-","kzz_stock_current":"-","kzz_convert_price":"-","kzz_covert_value":"-","kzz_cpr":"-","kzz_putback_price":"-","kzz_convert_time":"-","kzz_redempt_price":"-","kzz_straight_price":"-","kzz_stock_percent":"-","pb":"2.01","benefit_before_tax":"-","benefit_after_tax":"-","convert_bond_ratio":"-","totalissuescale":"-","outstandingamt":"-","maturitydate":"-","remain_year":"-","convertrate":"-","interestrtmemo":"-","release_date":"-","circulation":"-","par_value":"-","due_time":"-","value_date":"-","due_date":"-","publisher":"-","redeem_type":"T","issue_type":"3","bond_type":"-","warrant":"-","sale_rrg":"-","rate":"-","after_hour_vol":"-","float_shares":"97.09亿","float_market_capital":"2003.95亿","disnext_pay_date":"-","convert_rate":"-","volume_ratio":"0.56","percent5m":"0.05","psr":"0.9475","issue_type_name":"深股通","parsedtime":"04-14 15:04:03 (北京时间)","stockColor":"stockDown","afterColor":"-"};
# seajs.use(["SNB.dialog.js", "SNB.status.js", "SNB.singleStock.js", 'reward/reward_tooltip'])
# var pageId = window.location.pathname.split('/').pop();
# //- 页面进入统计
# var data = {
#   type: 1,
#   page: 45,
#   mod: 1,
#   data: {
#     symbol: pageId
#   }
# };
# Analytics(data);</script></div></div><div class="right-sidebar"><div class="wrapper"><div class="widget"><!--<Created>by victoryan on 15/11/19.</Created>--><div id="home-top-right" style="display:none;" class="mod"><div class="mod-bd"><a href="#" data-track-event="TopRight" target="_blank">topRight</a></div></div><script>(function ($) {
#   $.fn.isOnScreen = function(){
#     var element = this.get(0);
#     var bounds = element.getBoundingClientRect();
#     return bounds.top > $('#head').height() && bounds.bottom < $(window).height();
#   }
#   var isSingleStockPage = location.href.search('/S/') !== -1;
#   var topParams = {
#     platform_id: isSingleStockPage ? "0x06" : "0x05",
#     page_id: "0x05",
#     pos_id: "right_top"
#   }
#   var $homeTopRight = $('#home-top-right');
#   $.get('/promotion/display.json', topParams).done(function (data) {
#     if (data.ads && data.ads.length > 0) {
#       $homeTopRight.find('a')
#               .attr('href', data.ads[0].link || "javascript:void(0);")
#               .html('<img src="' + data.ads[0].image + '" style="display:block;width:100%;" />');
#       $homeTopRight.show();
#       seajs.use('common/util/analytics_post', function (analytics) {
#         var request = function (type) {
#           type = (type)? type : 'pv';
#           analytics.post({
#             type: '01',
#             page: isSingleStockPage? '45' : '44',
#             mod: '01',
#             data: {
#               url: data.ads[0].link,
#               category: type,
#               name: data.ads[0].promotion_id
#             }
#           });
#         };
#         request()
#         var isShown = false;
#         var debounce = null;
#         $(document).on('scroll', function () {
#           if (!$homeTopRight.isOnScreen()) {
#             isShown = false;
#           }
#           clearTimeout(debounce);
#           debounce = setTimeout(function () {
#             //- 是否完全展示在窗口中
#             if ($homeTopRight.isOnScreen()) {
#               //- 是否已经展示过
#               if (!isShown) {
#                 request();
#                 isShown = true;
#               }
#             }
#           }, 1000)
#         });
#         $homeTopRight.on('click', 'img', function () {
#           request('click');
#         });
#       });
#     }
#   });
# })(jQuery);</script><style>#home-top-right {
#   width: 100%;
#   margin-bottom: 20px;
# }</style></div><div class="widget"><style>.detailContent{
#   display:none;
# }
# .companyInfo strong.title{
#   margin-right:3px;
# }
# .companyInfo span.more,.companyInfo span.close{
#   color:#676767;
#   font-size:10px;
#   cursor:pointer;
#   margin-left:3px;
# }
# .stock-company{
#   margin-bottom:20px;
#   overflow:hidden;
#   font-size:13px;
#   line-height:20px;
# }
# .hide{
#   display:none;
# }
# .fold-all,.show-all{
#   color: #105bb6;
#   cursor:pointer;
#   text-align: right;
#   width: 60px;
#   display: inline-block;
# }
# .stock-company i{
#   width: 16px;
#   height: 16px;
#   display: inline-block;
#   background: url(https://assets.imedao.com/images/icons.png) no-repeat;
# }
# .stock-company .show-all i {
#   background-position: -133px -3px;
# }
#
# .stock-company .fold-all i{
#   background-position: -133px -20px;
# }</style><div class="stock-company "><p class="companyInfo summaryContent"><strong class="title">简介:</strong>    公司原系经深圳市人民政府深府办(1988)1509号文批准,于1988年11月1日在深圳现代企业有限公司基础上改组设立的股份有限公司,原名为"深圳万科企...<span class='show-all'>展开<i></i></span></p><p class="companyInfo detailContent"><strong class="title">简介:</strong>    公司原系经深圳市人民政府深府办(1988)1509号文批准,于1988年11月1日在深圳现代企业有限公司基础上改组设立的股份有限公司,原名为"深圳万科企业股份有限公司"。1991年1月29日,本公司发行之A股在深圳证券交易所上市。1993年5月28日,本公司发行之B股在深圳证券交易所上市。1993年12月28日经深圳市工商行政管理局批准更名为"万科企业股份有限公司"。<span class='fold-all'>收起<i></i></span></p><p class="companyInfo"><strong class="title">业务:</strong>房地产开发和物业服务。</p></div><script>seajs.use([], function(){
#   if($(".detailContent").length){
#     $(".stock-company span.show-all").click(function(){
#       $(".summaryContent").hide();
#       $(".detailContent").show();
#     })
#     $(".stock-company span.fold-all").click(function(){
#       $(".detailContent").hide();
#       $(".summaryContent").show();
#       $("html,body").animate({
#         scrollTop:0
#       })
#     })
#   }
# })</script></div><div class="widget"><style>.stock-events{
#   margin-bottom:20px;
# }
# .events-list{
#   font-size:12px;
# }
# .events-list li{
#   margin-bottom:10px;
#   //cursor:pointer;
# }
# .events-list li .title-wrapper{
#   margin-top:5px;
# }
# .events-list .event-time{
#   margin-right:15px;
# }
# .event-creator{
#   color:#888;
# }
# .events-list{
#   padding-top:14px;
# }
# .event-title{
#   line-height:16px;
# }</style><div class="stock-events head-list"><div class="titleContainer"><h2 class="widget-title">大事件</h2><!--span.changeAnother<a href="/s/SZ000002/calendar">更多</a>--></div><div class="fixit"></div><div class="events-list head-list"><ul></ul></div></div><script>seajs.use("SNB.base.js", function(){
#   SNB.get("/calendar/cal/events.json", { symbol: stockData.stockInfo.symbol, end_date: "INF", page: 1, count: 3 }, function(ret){
#     var html = "",
#         events = [];
#
#     for ( var key in ret ) {
#       events = events.concat(ret[key]);
#     }
#
#     events = events.reverse();
#
#     _.each(events, function(event){
#       /*
#       html += ' '
#         + '<li class="has-event" data-eventid="' + event.id + '">'
#           + '<div>'
#             + '<span class="event-time">' + SNB.Util.formatTime(event.start_date) + '</span>'
#             + '<span class="event-creator" data-cid="' + event.author_id + '"></span>'
#           + '</div>'
#           + '<div class="title-wrapper"><span class="event-title">' + event.title + '</span></div>'
#         + '</li>';
#       */
#       html += ' '
#       + '<li class="has-event" data-eventid="' + event.id + '">'
#       + '<div>'
#       + '<span class="event-time">' + SNB.Util.formatTime(event.start_date) + '</span>'
#       + '<span class="event-title">' + event.title + '</span>'
#       + '</div>'
#       + '</li>';
#     });
#
#     if ( !html ) {
#       //html = '<li class="no-event">该股票暂无大事件 <a href="/s/' + stockData.stockInfo.symbol + '/calendar#addEvent">我来添加</a></li>'
#       $(".stock-events").hide();
#     }
#
#     SNB.data.eventsList = true;
#     $(".events-list ul").html(html);
#     /*
#     // 显示创建者
#     $(".event-creator").each(function(){
#       var cid = $(this).data("cid"),
#           cname,
#           that = this;
#
#       function render(cid,cname){
#         var html = '创建者：' + '<a href="/' + cid + '" data-name="' + cname + '">@' + cname + '</a>';
#         $(that).html(html);
#       }
#
#       if ( cid == -1 ) {
#         cid = 3771154167;
#         cname = "雪球";
#         render(cid, cname);
#       } else {
#         SNB.get("/user/show.json", { id: cid }, function(user){
#           cname = user.screen_name;
#           render(cid,cname);
#         });
#       }
#     });
#
#     var timeout;
#
#     $(".events-list ul").on("mouseenter", "li.has-event", function(e){
#       if ( !$(this).hasClass("no-event") ) {
#         var id = $(this).data("eventid"),
#             event = _.find(events, function(e){
#               return e.id == id;
#             }),
#             that = this;
#
#         $(this).data("mouseState", "mouseenter");
#
#         setTimeout(function(){
#           var mouseState = $(that).data("mouseState");
#
#           if ( !mouseState || mouseState == "mouseenter" ) {
#             seajs.use("SNB.calendarDialog.js", function(){
#               var $eventDialog = SNB.dialog.eventShowDialog(event, $(that).find(".event-time"), "left");
#               $("#event-show-dialog").data("show", true);
#             });
#           }
#         }, 500);
#       }
#     }).on("mouseleave", "li.has-event", function(e){
#       $("#event-show-dialog").data("show", false);
#       $(this).data("mouseState", "mouseleave");
#       clearTimeout(timeout);
#       timeout = setTimeout(function(){
#         if ( !$("#event-show-dialog").data("show") ) {
#           $("#event-show-dialog").css("visibility", "hidden");
#         }
#       }, 200);
#     });
#
#
#     $("body").on("mouseenter", "#event-show-dialog", function(e){
#       $(this).data("show", true);
#     }).on("mouseleave", "#event-show-dialog", function(e){
#       $(this).data("show", false);
#       $(this).css("visibility", "hidden");
#     });
#     */
#   });
# });</script></div><div class="widget"><style>.stock-interview{
#   display:none;
# }
# .stock-interview .rightSider-list li{
#   padding:5px 0px 0px 0px;
#   margin-left:0px;
# }
# .stock-interview .rightSider-list{
#   margin-bottom:20px;
#   padding-top:5px;
# }</style><div class="stock-interview head-list"><h2 class="widget-title">公司访谈</h2><a href="/talks/all?symbol=SZ000002" target="_blank" class="changeAnother">更多</a><div class="fixit"></div><ul class="rightSider-list"></ul></div><script>(function(){
#   var symbol=stockData.stockInfo.symbol,
#       url="/interview/search.json?count=3&symbol="+symbol;
#
#   seajs.use("SNB.base.js",function(){
#     SNB.get(url,function(ret){
#       var html="";
#       _.each(ret.interviews,function(interview){
#         var title=interview.title;
#         if(SNB.Util.getWordsCount(title)>18){
#           title=SNB.Util.splitWord(title,18)+"...";
#         }
#         html+='<li><a href="'+interview.url+'" title="'+interview.title+'" target="_blank">'+title+'</a></li>'
#       })
#       if(html){
#         $(".stock-interview").show().find("ul").html(html);
#       }
#     })
#   })
# })()</script></div><div class="widget"><style>.stock-report{
#   display:none;
# }
# .stock-report .rightSider-list li{
#   padding:5px 0px 0px 0px;
#   margin-left:0
# }
# .stock-report .rightSider-list{
#   margin-bottom:20px;
#   padding-top:5px;
# }</style><div class="stock-report head-list"><h2 class="widget-title">雪球研报</h2><a href="/S/SZ000002/report" target="_blank" class="changeAnother">更多</a><div class="fixit"></div><ul class="rightSider-list"></ul></div><script>(function(){
#   var symbol=stockData.stockInfo.symbol,
#       url='/stockreport/list.json?symbol='+symbol+'&page=1&size=3';
#
#   seajs.use("SNB.base.js",function(){
#     SNB.get(url,function(ret){
#       var html="";
#       _.each(ret.list,function(report){
#         var title=report.title || symbol + '雪球研报';
#         if(SNB.Util.getWordsCount(title)>18){
#           title=SNB.Util.splitWord(title,18)+"...";
#         }
#         html+='<li><a href="/S/'+symbol+'/'+report.statusid+'" title="'+report.title+'" target="_blank">'+title+'</a></li>'
#       })
#       if(html){
#         $(".stock-report").show().find("ul").html(html);
#       }
#     })
#   })
# })()</script></div><div class="widget"><style>.stock-recommend{
#   display:none;
#   overflow:hidden;
#   margin-bottom:20px;
# }
# .stock-recommend .recommendContent{
#   margin:10px 0px;
#   font-size:12px;
#   line-height:1.5;
# }
# .stock-recommend .recommendContent .content{
#   float:left;
#   padding-left:10px;
#   width:166px;
# }
# .stock-recommend .recommendContent .content a{
#   max-width: 90px;
#   text-overflow: ellipsis;
#   overflow: hidden;
#   white-space: nowrap;
#   display: inline-block;
# }
# .stock-recommend .stockAnalystStatus{
#   margin-top:20px;
#   padding-left:5px;
# }
# .stockStatusInfo{
#   margin-top:10px;
#   overflow:hidden;
#   zoom:1;
# }
# .stockStatusInfo .time{
#   color:#999;
#   float:left;
# }
# .stockStatusInfo span{
#   float:right;
# }
# .recommendContent .userDes{
#   margin-top: 10px;
#   color: #A5A5A5;
# }
# .recommendContent{
#   zoom:1;
#   border-top: 1px solid #F1F1F1;
#   margin-top: 8px;
#   padding-top:10px;
# }</style><div class="stock-recommend head-list"><h2 class="widget-title">公司账号</h2><div class="fixit"></div></div><script>if(stockData.stockInfo.my_id){
#   seajs.use("SNB.stockRecommend.js",function(){
#     var ids=stockData.stockInfo.my_id.split(","),
#         urls=_.map(ids,function(id){
#           return SNB.domain.base+"/user/show.json?request_method=get&id="+$.trim(id);
#         }),
#         url=urls.join("#47bce5c74f#");
#
#     if(urls.length>1){
#       SNB.post("/apimerge/result.json",{api:url},function(ret){
#         var users=[];
#         for(var key in ret){
#           users.push(ret[key].result);
#         }
#         renderUsers(users);
#       })
#     }else{
#       SNB.get("/user/show.json",{id:_.first(ids)},function(user){
#         var users=[user];
#         renderUsers(users);
#       })
#     }
#     function renderUsers(users){
#       var collection=new SNB.Collections.stockRecommend(users),
#           views=new SNB.Views.stockRecommends({el:$(".stock-recommend"),collection:collection});
#       views.render();
#       $(".stock-recommend").show();
#     }
#   })
# }</script></div><div class="widget"><style>.stock-activeUser.loading{
#   background: url(https://assets.imedao.com/images/ajax-loader.gif) 50% no-repeat;
#   width: 100%;
# }
# .stock-activeUser{
#   display:none;
#   margin-bottom:20px;
# }
# .rightSider-list{
#   margin-bottom:0px;
# }
# .changeAnother{
#   line-height:1.5;
# }
# .changeAnother .prev{
#   display:none;
# }
# .changeAnother .last{
#   margin-left:10px;
# }
# .changeAnother a.unable{
#   color:#999;
#   cursor:default;
# }
# .stock-activeUser .titleContainer{
#   overflow:hidden;
#   zoom:1;
# }
# .rightSider-list .content .userDes{
#   cursor:pointer;
# }</style><div class="stock-activeUser head-list"><div class="titleContainer"><h2 class="widget-title">影响力</h2><span class="changeAnother"><a href="#" class="prev">上五位 </a><a href="#" class="last">下五位</a></span></div><div class="fixit"></div></div><script>seajs.use('SNB.stockActiveUser.js', function(){
#   SNB.get("/recommend/user/stock_hot_user.json",{symbol:stockData.stockInfo.stockid,start:0,count:6},function(ret){
#     if(ret&&ret.length){
#       var collection=new SNB.Collections.stockActiveUser(ret),
#           views=new SNB.Views.stockActiveUsers({el:$(".stock-activeUser"),collection:collection});
#       views.render();
#       $(".stock-activeUser").show();
#     }
#   })
# })</script></div><div class="widget"><style>.group-list{
#   margin-bottom:20px;
# }
#
# .group-list-hd{
#   border-bottom:1px solid #f1f1f1;
#   padding-bottom:8px;
# }
#
# .group-list .btn-recommand{
#   font-size:12px;
#   float:right;
# }
#
# .group-list .avatar{
#   border:1px solid #eee;
# }
#
# .group-item{
#   overflow:hidden;
#   zoom:1;
#   padding:10px 0 10px 4px;
#   font-size:12px;
# }
#
# .group-item-hd,
# .group-item-bd,
# .group-item-ft{
#   float:left;
# }
#
# .group-item-hd{
#   margin-right:10px;
#   width:50px;
# }
#
# .group-item-bd{
#   margin-right:10px;
#   width:105px;
# }
#
# .group-item-bd h4{
#   font-weight:normal;
#   overflow:hidden;
#   text-overflow:ellipsis;
#   white-space:nowrap;
#   width:100px;
#   margin:5px 0 15px;
# }
#
# .group-item-ft .btn-apply{
#   display:block;
#   background-color:#eee;
#   border:1px solid #e4e4e4;
#   color:#000;
#   text-align:center;
#   width:55px;
#   height:18px;
#   line-height:18px;
# }
#
# .group-item-ft .btn-apply:hover {
#   background-color:#05a;
#   border:1px solid #048;
#   color:#fff;
# }
#
# .star{
#   display:block;
#   width:120px;
#   height:12px;
#   overflow:hidden;
#   background:url('https://assets.imedao.com/images/icon_sprite_stars.png') no-repeat 0 0;
# }
#
# .star00{
#   background-position:0 -120px;
# }
#
# .star10{
#   background-position:0 -96px;
# }
#
# .star20{
#   background-position:0 -72px;
# }
#
# .star30{
#   background-position:0 -48px;
# }
#
# .star40{
#   background-position:0 -24px;
# }
#
# .star50{
#   background-position:0 0;
# }
# </style><div class="group-list"><div class="group-list-hd"><!--a.btn-recommand(href="#") 我要荐群--><h3>热门群组</h3></div><div class="group-list-bd"><div class="group-item"><div class="group-item-hd"><a href="/g/3851596884" target="_blank"><img src="//mavatar.imedao.com/158bf8067313ff633fe4c190-100.jpg" width="50" height="50" class="avatar"/></a></div><div class="group-item-bd"><h4><a href="/g/3851596884" target="_blank">万科</a></h4><span title="群组活跃度" class="star star10"></span></div><div class="group-item-ft"><a href="/g/3851596884" target="_blank" class="btn-apply">加入</a></div></div><div class="group-item"><div class="group-item-hd"><a href="/g/4044423276" target="_blank"><img src="//mavatar.imedao.com/158c0ca550f4031c3fd2c091-100.jpg" width="50" height="50" class="avatar"/></a></div><div class="group-item-bd"><h4><a href="/g/4044423276" target="_blank">万科股权持有群</a></h4><span title="群组活跃度" class="star star10"></span></div><div class="group-item-ft"><a href="/g/4044423276" target="_blank" class="btn-apply">加入</a></div></div><div class="group-item"><div class="group-item-hd"><a href="/g/4777394408" target="_blank"><img src="//mavatar.imedao.com/15389bbb46ec67e3fc4b1843-100.jpg" width="50" height="50" class="avatar"/></a></div><div class="group-item-bd"><h4><a href="/g/4777394408" target="_blank">万科基友会</a></h4><span title="群组活跃度" class="star star10"></span></div><div class="group-item-ft"><a href="/g/4777394408" target="_blank" class="btn-apply">加入</a></div></div><div class="group-item"><div class="group-item-hd"><a href="/g/8204927401" target="_blank"><img src="//mavatar.imedao.com/151e3d7aef52c7473fe61656-100.jpg" width="50" height="50" class="avatar"/></a></div><div class="group-item-bd"><h4><a href="/g/8204927401" target="_blank">万家灯火</a></h4><span title="群组活跃度" class="star star10"></span></div><div class="group-item-ft"><a href="/g/8204927401" target="_blank" class="btn-apply">加入</a></div></div></div></div></div><div class="widget"><style>.stock-follows .loading{
#   background: url(https://assets.imedao.com/images/ajax-loader.gif) 50% no-repeat;
#   width: 100%;
# }
# .stock-follows{
#   display:none;
#   margin-bottom:20px;
# }
# .stockFollower-list{
#   margin-bottom:0px;
# }
# .changeAnother{
#   line-height:1.5;
# }
# .follows-list,.events-list{
#   border-top:1px solid #f1f1f1;
#   padding-top:10px;
#   margin-top:5px;
#   padding-left:5px;
# }
# .follows-list .imgContainer{
#   display:inline-block;
#   margin-right:3px;
#   margin-bottom:3px;
#   zoom: 1;
#   *display: inline;
# }
#
# .stock-follows img{
#   width:30px;
#   height:30px;
# }</style><div class="stock-follows"><h2 class="widget-title"> <a id="followsCount" href="/S/SZ000002/follows"> </a>人关注了该股票</h2><div class="fixit"></div><div class="follows-list head-list"></div></div><script>seajs.use('SNB.stockFollowers.js')</script></div><div class="widget"><style>.stock-analyst{
#    display:none;
#    overflow:hidden;
# }
#  .stock-analyst .recommendContent{
#    margin:10px 0px;
#    font-size:12px;
#    line-height:1.5;
#  }
#  .stock-analyst .recommendContent .content{
#    float:left;
#    padding-left:10px;
#    width:166px;
#  }
#  .stock-analyst .stockAnalystStatus{
#    margin-top:20px;
#    padding-left:5px;
#    display:none;
#  }
#  .stock-analyst .userDes{
#    margin-top: 10px;
#    color: #A5A5A5;
#  }</style><div class="stock-analyst head-list"> <h2 class="widget-title">行业分析师</h2><div class="fixit"></div></div><script>if(stockData.stockInfo.analyst_id){
#   seajs.use("SNB.stockRecommend.js",function(){
#     var ids=stockData.stockInfo.analyst_id.split(","),
#         urls=_.map(ids,function(id){
#           return SNB.domain.base+"/user/show.json?request_method=get&id="+$.trim(id);
#         }),
#         url=urls.join("#47bce5c74f#");
#
#     if(urls.length>1){
#       SNB.post("/apimerge/result.json",{api:url},function(ret){
#         var users=[];
#         for(var key in ret){
#           users.push(ret[key].result);
#         }
#         renderUsers(users);
#       })
#     }else{
#       SNB.get("/user/show.json",{id:_.first(ids)},function(user){
#         var users=[user];
#         renderUsers(users);
#       })
#     }
#     function renderUsers(users){
#       var collection=new SNB.Collections.stockRecommend(users),
#           views=new SNB.Views.stockRecommends({el:$(".stock-analyst"),collection:collection});
#       views.render();
#       $(".stock-analyst").show();
#     }
#   })
# }</script></div><div class="widget"><style>#alsoFollow, #relatedIndustry {
#   margin-bottom: 20px;
# }
# </style><style>.new-portfolio{
#   display:none;
# }
# .new-portfolio{
#   color:black;
# }
# .new-portfolio table tbody tr.gray{
#   background-color:#F9F9F9;
# }
# .new-portfolio table thead th.sortable{
#   color:#999999;
#   font-weight:normal;
#   cursor:normal;
# }
# .new-portfolio table{
#   margin:10px 0px 0px 0px;
# }
# .tableContent{
#   border-top:1px solid #F1F1F1;
#   margin-top:6px;
# }
# .tableContent table.portfolio{
#   margin-top:3px;
# }</style><div id="alsoFollow" class="new-portfolio"><h2 class="widget-title">大家还关注</h2><div class="fixit"></div><div class="tableContent"><table cellspacing="0" cellpadding="0" class="portfolio"><thead><tr><th data-key="code" class="sortable">股票</th><th data-key="current" class="sortable">当前价</th><th data-key="percentage" class="sortable">涨跌幅</th></tr></thead><tbody></tbody></table></div></div><div id="relatedIndustry" class="new-portfolio"><h2 class="widget-title"></h2><div class="fixit"></div><div class="tableContent"><table cellspacing="0" cellpadding="0" class="portfolio"><thead><tr><th data-key="code" class="sortable">股票</th><th data-key="current" class="sortable">当前价</th><th data-key="percentage" class="sortable">涨跌幅</th></tr></thead><tbody></tbody></table></div></div><script>var apiKey="47bce5c74f";
# var isMF = stockData && stockData.stockInfo && stockData.stockInfo.isMF;
# var isTP = stockData && stockData.stockInfo && stockData.stockInfo.isTP;
# var isFP = stockData && stockData.stockInfo && stockData.stockInfo.isFP;
# var isPF = stockData && stockData.stockInfo && stockData.stockInfo.isPF;
# seajs.use("SNB.renderTableTrHtml.js", function (exports) {
#   function generateTable(quotes, isMF, isTP){
#     var html="";
#     for(var i=0,ii=quotes.length;i<ii;i++){
#       var quote = quotes[i];
#
#       if ( !isTP && !isFP && !isPF ) {
#         quote.change = "";
#       }
#       html += exports.generateTableTrHtml(i, quote)
#     }
#     return html;
#   }
#
#   $(function(){
#     var url = "/stock/industry/stockList.json",
#       symbol = stockData.stockInfo.stockid,
#       params = {
#         type: 1,
#         code: symbol,
#         size: 8
#       };
#
#     if ( isTP ) {
#       params = {
#         symbol: symbol,
#         count: 8
#       };
#       url = "/trust/industry/list.json";
#     }
#     if ( isFP ) {
#       params = {
#         page: 1,
#         size: 8,
#         order: "desc",
#         orderby: "SALEBEGINDATE",
#       }
#       url = "/financial_product/query.json";
#     }
#     if ( isPF ) {
#       params = {
#         count: 10
#       }
#       url = "/private_fund/industry/list.json";
#     }
#
#     SNB.get(url, params, function(ret){
#       var quotes = ret.industrystocks || ret.data;
#       if ( quotes && quotes.length ) {
#         if ( isMF ) {
#           _.each(quotes, function(quote){
#             quote.name = SNB.Util.splitWord(quote.name, 5);
#             quote.isMF = true;
#           });
#         }
#         if ( isTP ) {
#           _.each(quotes, function(quote){
#             quote.name = SNB.Util.splitWord(quote.name, 5);
#             quote.isTP = true;
#             quote.tpType = ret.type;
#
#             if ( ret.type == 1 ) {
#               quote.current = quote.million_gain;
#               quote.percentage = quote.seven_day_yield;
#             } else {
#               quote.current = quote.unit_nav;
#               quote.percentage = quote.acc_yield;
#             }
#             ret.exchange = "TP";
#             ret.industryname = "信托";
#           });
#         }
#         if ( isFP ) {
#           _.each(quotes, function(quote){
#             quote.name = SNB.Util.splitWord(quote.name, 5);
#             quote.isFP = true;
#             quote.percentage = quote.expt_yield * 100;
#             quote.current = quote.entrust_period_std;
#             ret.exchange = "FP";
#             ret.industryname = "理财产品";
#           });
#         }
#         if ( isPF ) {
#           _.each(quotes, function(quote){
#             quote.name = SNB.Util.splitWord(quote.name, 5);
#             quote.isPF = true;
#             quote.change = quote.fund_share;
#             quote.current = quote.unit_nav;
#             ret.industryname = "私募基金";
#           });
#         }
#         $("#relatedIndustry").find("tbody").html(generateTable(quotes, isMF, isTP)).end().show().find("table").data("stocks", quotes);
#         var industryUrl = SNB.Util.getNewStocklistUrl(ret.industryname, ret.platename, ret.exchange);
#         $("#relatedIndustry").find("h2").html("行业：<a href='" + industryUrl + "'>"+ret.industryname+"</a>");
#         //$("#relatedIndustry").find("h2").html("行业：<a href='/hq/"+ret.exchange+"/"+encodeURIComponent(ret.industryname)+"'>"+ret.industryname+"</a>");
#
#         // 信托分两种情况  表头也要相应变化
#         if ( isTP && ret.type == 1 ) {
#           $("#relatedIndustry").find("table thead tr th").eq(1).text("万份收益");
#           $("#relatedIndustry").find("table thead tr th").eq(2).text("七日年化收益");
#         }
#       }
#     });
#
#     SNB.get("/stock/portfolio/popstocks.json",{code:stockData.stockInfo.stockid,start:0,count:8},function(ret){
#       var quotes=ret;
#       if(quotes&&quotes.length){
#         $("#alsoFollow").find("tbody").html(generateTable(quotes)).end().show().find("table").data("stocks",quotes);
#       }
#     })
#   })
# })</script></div><div class="widget"><!--<Created>by victoryan on 15/11/19.</Created>--><div id="home-bottom-right" style="display:none;" class="mod"><div class="mod-bd"><a href="#" data-track-event="BottomRight" target="_blank">bottomRight</a></div></div><script>(function ($) {
#   var isSingleStockPage = location.href.search('/S/') !== -1;
#   var bottomParams = {
#     platform_id: isSingleStockPage ? "0x06" : "0x05",
#     page_id: "0x05",
#     pos_id: "right_bottom"
#   }
#   var $homeBottomRight = $('#home-bottom-right');
#   $.get('/promotion/display.json', bottomParams).done(function (data) {
#     if (data.ads && data.ads.length > 0) {
#       $homeBottomRight.find('a')
#               .attr('href', data.ads[0].link || "javascript:void(0);")
#               .html('<img src="' + data.ads[0].image + '" style="display:block;width:100%;" />');
#       $homeBottomRight.show();
#       seajs.use('common/util/analytics_post', function (analytics) {
#         var request = function (type) {
#           type = (type)? type : 'pv';
#           analytics.post({
#             type: '01',
#             page: isSingleStockPage? '45' : '44',
#             mod: '02',
#             data: {
#               url: data.ads[0].link,
#               category: type,
#               name: data.ads[0].promotion_id
#             }
#           });
#         };
#         request();
#         var isShown = false;
#         var debounce = null;
#         $(document).on('scroll', function () {
#           if (!$homeBottomRight.isOnScreen()) {
#             isShown = false;
#           }
#           clearTimeout(debounce);
#           debounce = setTimeout(function () {
#             //- 是否完全展示在窗口中
#             if ($homeBottomRight.isOnScreen()) {
#               //- 是否已经展示过
#               if (!isShown) {
#                 request();
#                 isShown = true;
#               }
#             }
#           }, 1000)
#         });
#         $homeBottomRight.on('click', 'img', function () {
#           request('click');
#         });
#       });
#     }
#   });
# })(jQuery);</script><style>#home-bottom-right {
#   width: 100%;
#   margin-bottom: 20px;
# }</style></div></div></div></div><div id="footer"><div class="copyright"><a href="/about/faq" target="_blank">常见问题</a><a href="/about/contact-us" target="_blank">联系方式</a><a href="/about/jobs" target="_blank">加入我们</a><a href="https://danjuanapp.com/" target="_blank">蛋卷基金</a><a href="/about/what-is-xueqiu" target="_blank">关于雪球</a><a>© 2017 XUEQIU.COM</a><br><a href="http://xqimg.imedao.com/14ee3530b118403fee048f5b.png" target="_blank">京ICP证100666号</a><a href="http://www.miibeian.gov.cn" target="_blank">京ICP备10040543</a><a>京公网安备11010502026957</a><a href="http://xqimg.imedao.com/14d52aefd15e8f3fc0ce1fbd.png" target="_blank">证券业协会会员单位(代码817027)</a><p>风险提示：雪球里任何用户或者嘉宾的发言，都有其特定立场，投资决策需要建立在独立思考之上。</p></div></div><link rel="stylesheet" href="https://assets.imedao.com/style/common/regist-guide-2ecd55.css"><div class="regist-guide-container"><div class="regist-guide-main"><div class="regist-guide-text"><p>雪球社区汇集了千万投资者，提供沪深港美股票</p><p>实时行情、实战交流、实盘交易</p></div><a href="" class="regist-guide-button">30秒完成注册 ></a></div></div><script>seajs.use(['widget/util/regist-guide']);</script><script>var _hmt = _hmt || [];
# (function () {
#   var hm = document.createElement("script");
#   hm.src = "https://hm.baidu.com/hm.js?1db88642e346389874251b5a1eded6e3";
#   var s = document.getElementsByTagName("script")[0];
#   s.parentNode.insertBefore(hm, s);
# })();</script><script>var _gaq = _gaq || [];
# _gaq.push(['_setAccount', 'UA-16079156-4']);
# _gaq.push(['_setDomainName', 'none']);
# _gaq.push(['_trackPageview']);
#
# (function () {
#   var ga = document.createElement('script');
#   ga.type = 'text/javascript';
#   ga.async = true;
#   ga.src = ('https:' == document.location.protocol ? 'https://ssl' : 'http://www') + '.google-analytics.com/ga.js';
#   var s = document.getElementsByTagName('script')[0];
#   s.parentNode.insertBefore(ga, s);
# })();
#
# window.onerror = function (message, file, line) {
#   var sFormattedMessage = '[' + file + ' (' + line + ')]' + message;
#   _gaq.push(['_trackEvent', 'Exceptions', 'Application', sFormattedMessage, null, true]);
# }</script><script>if (window.jQuery) {
#   jQuery(function ($) {
#     $('.cube-invite').on('click', function () {
#       var href = $.trim($(this).attr('href'));
#       if (window._hmt) {
#         _hmt.push(['_trackEvent', 'cube-invite', 'click', href]);
#       }
#     });
#   });
# }</script></body></html>

# %%
headers = {
"Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8",
"Accept-Encoding":"gzip, deflate, sdch, br",
"Accept-Language":"zh-CN,zh;q=0.8,en-US;q=0.6,en;q=0.4",
"Cache-Control":"max-age=0",
"Connection":"keep-alive",
"Cookie":"bid=e2201b22d6ecc5fd4dd7994cfe7b5c6c_imznpt8g; s=6g1g0ghdwc; u=221490945723339; xq_a_token=ca292f8d934efc28f3fd052b7dcf46f14a20a0d3; xq_a_token.sig=OfkwBmKBwnYETfT5NOuElwVwhBY; xq_r_token=d1accc7b0cafd743be1b975a863a146e514d9c80; xq_r_token.sig=LV5APomGXuF1PJGnH9SmAPdxYHc; aliyungf_tc=AQAAAAP7YVVJngcA4thzfHHCckmnWGU6; Hm_lvt_1db88642e346389874251b5a1eded6e3=1490945724,1491549758; Hm_lpvt_1db88642e346389874251b5a1eded6e3=1491550521; __utmt=1; __utma=1.1616022943.1457004958.1488871387.1491549769.13; __utmb=1.3.10.1491549769; __utmc=1; __utmz=1.1488871387.12.4.utmcsr=xueqiu.com|utmccn=(referral)|utmcmd=referral|utmcct=/",
"Host":"xueqiu.com",
"Upgrade-Insecure-Requests":"1",
"User-Agent":"Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/56.0.2924.87 Safari/537.
��活的官场现形记，也记录了一个高速发展中的国家，正在经历的繁荣转变、矛盾挣扎……不同阶层、不同职业背景的人，能从中看到不是绝对的善恶与是非。<br/><br/>　　这个春天，包括00后、90后在内的数以亿计人民齐追一部《人民的名义》，看到戏如生活看到人生如戏，就连达康书记的“欧式双眼皮”日后都将成为全民又一份珍贵的共同记忆啊，快哉快哉！","created_at":1492316878000,"retweet_count":1,"reply_count":1,"fav_count":0,"truncated":false,"commentId":0,"retweet_status_id":0,"symbol_id":null,"description":"官场现形记：一部《人民的名义》，为何看哭一群民营企业家？2017-04-16 07:23 微信公众号：创业投资家 江直竖 一位企业家朋友说，看《人民的名义》，他时常感觉“扎心了老铁”！在民营企业当前遭遇的问题中，扭曲的政商、企业与银行间的关系，剧中都难得地提到了。 1 企业贷款之难 在剧中，商人蔡...","type":"2","source_link":"http://xueqiu.com/about/mobile-xueqiu","edited_at":null,"pic":"","user":{"subscribeable":false,"remark":null,"status":1,"common_count":0,"domain":null,"type":"1","location":null,"description":"当寒冬走过，生命将欣欣向荣，生生不息…………","id":5177736766,"url":null,"follow_me":false,"following":false ...

# %%
import json
import bs4
text = ""
decode_json = json.loads(content)
cont = decode_json["list"][5]["text"]
soup = BeautifulSoup(cont)
# print type(soup.body.contents[0])
# for child in soup.body.contents[0].children:
#     if isinstance(child,bs4.element.NavigableString):
#         print child
# j = 0
# if isinstance(soup.body.contents[j], bs4.element.NavigableString) or isinstance(soup.body.contents[j], bs4.element.Tag) :
#     if  isinstance(soup.body.contents[j], bs4.element.Tag):
#         print soup.body.contents[j].string
        
#     else:
# #         if soup.body.contents[j]==" ":
# #             continue
#         print soup.body.contents[j]
    
import time
ISOTIMEFORMAT="%Y-%m-%d %X"

for i in range(len(decode_json["list"])):
    cont = decode_json["list"][i]["text"]
    soup = BeautifulSoup(cont)
    for j in range(len(soup.body.contents)):
        if isinstance(soup.body.contents[j], bs4.element.NavigableString) or isinstance(soup.body.contents[j], bs4.element.Tag) :
            if  isinstance(soup.body.contents[j], bs4.element.Tag):
                if soup.body.contents[j].string != None:
                    print soup.body.contents[j].string
                else:
                    for child in soup.body.contents[j]:
                        if isinstance(child,bs4.element.NavigableString):
                            print child
                        
            else:
                if soup.body.contents[j]==" ":
                    continue
                print soup.body.contents[j]
    time_text = decode_json["list"][i]["created_at"] #生成时间
    print time.strftime( ISOTIMEFORMAT, time.localtime((float(time_text)/1000)) )
# Out:
# 官场现形记：一部《人民的名义》，为何看哭一群民营企业家？
# 2017-04-16 07:23 微信公众号：创业投资家　 江直竖
#
# 一位企业家朋友说，看《人民的名义》，他时常感觉“扎心了老铁”！在民营企业当前遭遇的问题中，扭曲的政商、企业与银行间的关系，剧中都难得地提到了。
# 　　1
# 　　企业贷款之难
# 　　在剧中，商人蔡成功是个让人又爱又恨的角色。
# 　　他并非唯利是图的阴险小人，却也不是诚实守信之人。在他的大风厂经营困难时，他四处借贷直至债台高筑，无力偿还。
# 　　在前面的剧情中，借蔡成功之口，编剧道出了普通民营企业在传统金融机构贷款难问题。
# 　　真实情况是如此吗？
# 2017-04-16 10:52:16
# 假如没有出租类物业，恒隆的经营生命期基本就结束了，恒隆做的并不是买地的周期，而是把一次性收益的出售业务转移到长期经营的出租类业务，龙湖现在也是这个方向
#        所谓周期操作，是一个理想化的想法，抄底需要地产行业在底部，除了自己有钱，还得能借到低成本的钱才可以，最好别的公司没有钱，需要你并购，而且这些需要并购的公司只是没有钱，而不能是一堆烂账，最难的是，你抄底之后，市场得尽快好起来，不然抄底的利息就成了累赘，这太难了
#        逆势去抄底的公司，很大原因是因为自己规模和业务分布有问题，万科这种规模的公司，拿几块错地，也不会有什么问题，中小规模的公司，在一线城市拿几块错地，就得退出房地产市场了，所以这两年最大的市场变化就是，大公司去收权益，或者联合拍地合作，小公司逐渐淡出市场，大公司变那么大并不是逆势拍了很多地，而是很多小公司决定不玩了，因为玩不起了
# //
# :回复
# :试图把握房地产周期的地产公司，基本被市场打得鼻青脸肿；不管不顾持续加杠杆的，赚得盆满钵满；认为自己把握不了周期，以效率和品牌取胜的，被野蛮人举了牌。作为投资者，你喜欢哪种？
# =======
# 尝试回答下：
# 1）试图把握房地产周期的地产公司，基本被市场打得鼻青脸肿？
# 因为，那家地产公司不是真懂房地产周期性。真懂的
#  ，活的好滋润。
# 2）不管不顾持续加杠杆的，赚得盆满钵满？
# 短期，好绚烂的；长期，干着干着就不行啦。例如：万达，绿地。。。
# 3）认为自己把握不了周期，以效率和品牌取胜的，被野蛮人举了牌。
# 因为野蛮人，不野蛮，更懂企业。
# 4）作为投资者，您喜欢那种？
# 不可知道，适度分散以应对。
# 2017-04-16 10:28:55
# 回复
# : 一帮人，看多看空得说出道理来，像你这样的讲法就显得比较客观理性了，华夏至少是中国未来排前三的地产公司，就算下周调整一周，未来股价都一定会突破现在的价格，这是一家未来极度可期的公司，懂的人自然会懂//
# :回复
# :看成交量就说是顶不靠谱 万科去年7月单日200亿 下跌了不到半个月开启翻倍行情。华夏是不是顶要看手里的地从新估值后对应市值  这个真认真研究下 我没研究 如果地真是增值了 这里就不是顶 增值预期加上情绪  涨到5千亿也不是没可能
# 2017-04-16 09:18:50
# 导语
# 近日，住房和城乡建设部、国土资源部联合发布《关于加强近期住房及用地供应管理和调控有关工作的通知》。意欲通过改变土地供应量，来人为的控制市场的供求关系，从而达到控制房价的目的。本期，笔者就和大家一起来探讨上述政策的“药力”如何。
# 1.政策内容及解读
# 如果说此前限购限贷是从需求侧进行控制的话，那现在便是从土地供应，这一
# 新规更加明确了房价上涨快，上涨大的城市和去存存城市间的差异化对待。简单来说，涨的多的城市不要再涨了，去库存的城市不要再拍地了。
# 对于向后的各地土地供应将实施统一化管理，6月底之前必须上报中期和远期规划，这样一来，部分城市土地供应的随意性将会大幅减少。
# 而且，新规对土地供应和去库存周期之间出台了明确的量化规定：
# 房产库存去化周期通常计算方法：
# 去化周期=当年待售库存面积/月均销售面积
# （一般来说，单个城市区域去化周期小于6个月，房价就存在上行的压力；如果大于12个月，就存在下行的压力。）
# 规定的量化，对于之前某些城市人为减少供地推到房价以及城市土地供应的随意性能够起到较好的限制与规范。
# 就在新规发布的第二天，北京市立马进行跟进发布《北京市2017-2021年及2017年住宅用地供应规划》。今后五年北京将供应住宅用地6000公顷，保障150万套住房建设需求。
# 上面的新规内容中，还有一条规定尤为重要：
# 这条规定基本上宣告了“地王”的破灭，作为背锅小能手，每次土拍时“地王”的高溢价，总会给购房者带来恐慌，继而助推周边房价的快速上涨。
# 新规中的“限房价、竞地价”、“限地价、竞房价”、超过溢价率一定比例后现房销售或竞自持面积等政策，目前已经在部分城市施行，比如苏州和南京等地的“摇奖式”土拍以及相关溢价现房销售的规定。相信后续会有更多的城市跟进施行。
# 没有了“地王”，群龙无首会是怎样一种画面，至少在苏州施行土拍新政后来看，虽然还有其他因素的影响，但确实没有之前逢拍必涨的情况发生。
# 新规对开发商层面同样进行了限制。要求开发商及时足额缴纳土地出让金、按照合同及时开工竣工、对拖延上市和捂盘惜售的进行严厉查处。
# 在变相上调利率，整个房地产市场杠杆相对较大的背景下，对房地产开发企业强制降杠杆，不让其他渠道的资金流入房地产市场，必然会增加相关企业的资金压力，尤其是那些资金流紧张的小房产企业，
# 后续很有可能会出现手握大把现金流却没有土地的大房企，和手握土地，但现金流出现断裂的小房企之间的大吃小，大小合作的情况发生。
# 比如，手握870亿现金的万科，在3月份公布的2016年的年报中提出：
# 2017年随着行业回归理性吗，前期部分高价获取的项目存在潜在的并购机会。本集团将积极关注土地存量市场的合作机会，充分发挥资金优势，加强和各类机构的合作，采取更加灵活的合作方式，发掘盘活优质的项目资源。
# 房屋租赁市场，后续将成为重点发展的方向。无论是公租房面积的增加，鼓励个人房屋出租，还是厂房改建房屋租赁，
# 总得让买不起房的老百姓有个住的地方，这点确实要手动点赞。
# 目前出台的地方政策来看，以北京来说，在2017年计划新建的30万套住宅中，租赁租房就有10万套之多，占比整个供应的30%多。
# 强化约谈问责制度，这一点虽然内容少，但在我们这个神奇的地方，确是短期影响房价最为重要的因素（没有之一）。毕竟谁也不想自己的仕途毁于房价之手。
# 另外，还有一点值得关注的是：
# 这也是目前部分城市采用的降房价的手段之一，通过扩大计算区域，压制网签数量等进行人为控制。若后续真能严查，必定会对整个房产市场产生积极的作用......
# 2.新规解读总结
# 土地供应集中统一备案管理
# 根据去化周期决定土地供应程度
# 夺人眼球的“地王”将不复存在
# 强制降杠杆，严查开放商资金来源
# 大力发展房屋租赁市场，扩大市场规模
# 强化约谈问责制度，严查数据造假行为
# 3.后续房价走势如何？
# 首先，我们不能简单孤立的来看本次两部委出台的新规，而要结合之前出台的一系列限购限贷等政策统筹考虑。
# 在“房子是用来住的，不是用来炒的”大前提下，从前至后陆陆续续出台的政策都指向同一个目标：控制房价上涨。
# 结合本次新规，笔者认为：
# 未来2-3年内，整体来看，1,2线房价将维持区间震荡，略有下降的趋势。而3,4线城市将迎来去库存的良机。
# 针对1,2线城市，如果你有购房需求，可以开始慢慢看房，现在已经从之前的卖方市场，转变为买方市场。只要政策维持目前态势，未来2-3年，整个市场都不会有大的变化。多走走看看，买房子毕竟不像买白菜，不喜欢了大不了扔掉。如果买的房子不喜欢，要换房的话，你还要承担相当的摩擦成本。所以，趁现在买房市场，对周边配套、环境、房子质量等多了解了解，避免吃亏上当，买到“假”的房子。
# 对于3,4线城市，如果你是刚需自住，房价近两年涨幅不算离谱的话（笔者认为没有超过30%左右），还是入手为好，毕竟房子牵扯到包括结婚、孩子上学等一系列问题。如果你是投资的话，笔者劝你还是算了。即使未来出现涨幅，但这也是在特殊政策的影响之下发生的。等潮水褪去，大部分区域流动性将成为很大的问题，相比较而言，风险收益比太大，不值得投资。
# 苏州房势（微信公众号ID：szfs2017）原创，欢迎关注公众号原创内容~
# 2017-04-16 09:15:09
# 回复
# : 承蒙谬赞，共同学习哈。
# 你的回复，我完全赞同。
# 至于资产集中的问题，我也曾想与
#  的海港城比较，但还是时间精力有限哦。//
# :回复
# :佩服，佩服啊！您这读懂企业的能力太强啦吧。
# 我尝试回答如下，未必正确呐。
# 1.大股东持股比例太高，以前也担心过会不会私有化。
# 答：中方+嘉里，超过80%。细看，真正大股东是，商务部（原来对外经贸部），副部长高燕是董事长，这是党的资产。
# 2.大股东参与上市公司项目建设，不大气，理念不对，应由上市公司建设，控股股东以市值管理来获得价值增长。
# 答：没错！党的企业，都这样。
# 3.管理层已老化，洪敬南已届七旬，由嘉里系成员主导的管理体系将有变动，而中方可能并无合适人选。
# 答：没错！不过，香港收租股的管理层都年龄偏大，似乎养老股都那样。
# 4.上市公司固守一隅，资产太集中，对嘉里系而言，国贸中心是他全球资产的一个配置，而对上市公司而言则是全部，风险太集中，除有经营管理市场需求变动风险，还有安保、消防，誉情风险等。所以其20多亿的贷款以银团贷款的方式授信发放，不过他的财务政策也确实较为保守。他的投资性房地产是以历史成本入账，且有要折旧的，这种财务处理方式，我喜欢。
# 答：没错，完全正确。反过来看，上市公司没有多地发展，多元发展，倒是很少犯错的，例如：希慎兴业，居铜锣湾，只要出手买地，就犯错。
# 5.从1999年上市以来包括2016年的分红，其分红总额（税前，我计算的）每股2.797元，其IPO价格为每股5.40元（粗略计算），所以他的分红率未必高。
# 答：上市18年，历史平均分红率40%，以净利润为基数。分红率=年度股息總額/經營業務流入現金淨額 Net cash provided by operating activities=23%。比万科相当可以，比恒隆/希慎兴业差距好大。
# 6所以，这个公司，我认为现在的价格还是高了些，如有2PB左右的买入机会，倒是一件美事哈。
# 答：没错！您这是捡狗头金呐，那就一起耐心等哈，大概相当与2.5万-3万，买下国贸，怎么也赚个几倍吧，房子没有办法张腿跑啦。
# 2017-04-16 08:02:22
# 回复
# : 佩服，佩服啊！您这读懂企业的能力太强啦吧。
# 我尝试回答如下，未必正确呐。
# 1.大股东持股比例太高，以前也担心过会不会私有化。
# 答：中方+嘉里，超过80%。细看，真正大股东是，商务部（原来对外经贸部），副部长高燕是董事长，这是党的资产。
# 2.大股东参与上市公司项目建设，不大气，理念不对，应由上市公司建设，控股股东以市值管理来获得价值增长。
# 答：没错！党的企业，都这样。
# 3.管理层已老化，洪敬南已届七旬，由嘉里系成员主导的管理体系将有变动，而中方可能并无合适人选。
# 答：没错！不过，香港收租股的管理层都年龄偏大，似乎养老股都那样。
# 4.上市公司固守一隅，资产太集中，对嘉里系而言，国贸中心是他全球资产的一个配置，而对上市公司而言则是全部，风险太集中，除有经营管理市场需求变动风险，还有安保、消防，誉情风险等。所以其20多亿的贷款以银团贷款的方式授信发放，不过他的财务政策也确实较为保守。他的投资性房地产是以历史成本入账，且有要折旧的，这种财务处理方式，我喜欢。
# 答：没错，完全正确。反过来看，上市公司没有多地发展，多元发展，倒是很少犯错的，例如：希慎兴业，居铜锣湾，只要出手买地，就犯错。
# 5.从1999年上市以来包括2016年的分红，其分红总额（税前，我计算的）每股2.797元，其IPO价格为每股5.40元（粗略计算），所以他的分红率未必高。
# 答：上市18年，历史平均分红率40%，以净利润为基数。分红率=年度股息總額/經營業務流入現金淨額 Net cash provided by operating activities=23%。比万科相当可以，比恒隆/希慎兴业差距好大。
# 6所以，这个公司，我认为现在的价格还是高了些，如有2PB左右的买入机会，倒是一件美事哈。
# 答：没错！您这是捡狗头金呐，那就一起耐心等哈，大概相当与2.5万-3万，买下国贸，怎么也赚个几倍吧，房子没有办法张腿跑啦。//
# :回复
# :以前读过
#  ，后来放下了，这两天又读了一下，个人浅见，作个标记。
# 1.大股东持股比例太高，以前也担心过会不会私有化。
# 2.大股东参与上市公司项目建设，不大气，理念不对，应由上市公司建设，控股股东以市值管理来获得价值增长。
# 3.管理层已老化，洪敬南已届七旬，由嘉里系成员主导的管理体系将有变动，而中方可能并无合适人选。
# 4.上市公司固守一隅，资产太集中，对嘉里系而言，国贸中心是他全球资产的一个配置，而对上市公司而言则是全部，风险太集中，除有经营管理市场需求变动风险，还有安保、消防，誉情风险等。所以其20多亿的贷款以银团贷款的方式授信发放，不过他的财务政策也确实较为保守。他的投资性房地产是以历史成本入账，且有要折旧的，这种财务处理方式，我喜欢。
# 5.从1999年上市以来包括2016年的分红，其分红总额（税前，我计算的）每股2.797元，其IPO价格为每股5.40元（粗略计算），所以他的分红率未必高。
# 所以，这个公司，我认为现在的价格还是高了些，如有2PB左右的买入机会，倒是一件美事哈。
# 2017-04-16 07:52:21

# %%
import numpy as np
import sys
import re
import codecs
import os
import jieba
from gensim.models import word2vec
from sklearn.cross_validation import train_test_split
from sklearn.externals import joblib
from sklearn.preprocessing import scale
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from scipy import stats
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation
from keras.optimizers import SGD
from sklearn.metrics import f1_score
from bayes_opt import BayesianOptimization as BO
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

def parseSent(sentence):
    seg_list = jieba.cut(sentence)
    output = ''.join(list(seg_list)) # use space to join them
    return output
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-148-838a08d6ab82> in <module>()
#      12 from sklearn.decomposition import PCA
#      13 from scipy import stats
# ---> 14 from keras.models import Sequential
#      15 from keras.layers import Dense, Dropout, Activation
#      16 from keras.optimizers import SGD
#
# c:\python27\lib\site-packages\keras\__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import activations
#       4 from . import applications
#       5 from . import backend
#
# c:\python27\lib\site-packages\keras\activations.py in <module>()
#       1 from __future__ import absolute_import
#       2 import six
# ----> 3 from . import backend as K
#       4 from .utils.generic_utils import deserialize_keras_object
#       5
#
# c:\python27\lib\site-packages\keras\backend\__init__.py in <module>()
#      71 elif _BACKEND == 'tensorflow':
#      72     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 73     from .tensorflow_backend import *
#      74 else:
#      75     raise ValueError('Unknown backend: ' + str(_BACKEND))
#
# c:\python27\lib\site-packages\keras\backend\tensorflow_backend.py in <module>()
# ----> 1 import tensorflow as tf
#       2 from tensorflow.python.training import moving_averages
#       3 from tensorflow.python.ops import tensor_array_ops
#       4 from tensorflow.python.ops import control_flow_ops
#       5 from tensorflow.python.ops import functional_ops
#
# ImportError: No module named tensorflow
